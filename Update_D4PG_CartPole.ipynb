# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import random
import matplotlib.pyplot as plt

# Set random seed for reproducibility
SEED = 42
random.seed(SEED)
torch.manual_seed(SEED)
np.random.seed(SEED)

# Custom wrapper for continuous CartPole
class ContinuousCartPoleWrapper(gym.Env):
    def __init__(self, env):
        self.env = env
        self.action_space = gym.spaces.Box(low=0, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = self.env.observation_space

    def step(self, action):
        discrete_action = 0 if action < 0.5 else 1
        obs, reward, done, info = self.env.step(discrete_action)
        return obs, reward, done, info

    def reset(self):
        return self.env.reset()

    def render(self):
        self.env.render()

    def close(self):
        self.env.close()


# Define the Actor Network
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Actor, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, action_dim),
            nn.Sigmoid(),  # Logistic output
        )

    def forward(self, state):
        return self.net(state)


# Define the Distributional Critic Network
class DistributionalCritic(nn.Module):
    def __init__(self, state_dim, action_dim, atoms, v_min, v_max):
        super(DistributionalCritic, self).__init__()
        self.atoms = atoms
        self.v_min = v_min
        self.v_max = v_max
        self.delta_z = (v_max - v_min) / (atoms - 1)
        self.support = torch.linspace(v_min, v_max, atoms)
        self.net = nn.Sequential(
            nn.Linear(state_dim + action_dim, 128),
            nn.ReLU(),
            nn.Linear(128, atoms),
        )

    def forward(self, state, action):
        q_values = self.net(torch.cat([state, action], dim=1))
        probs = torch.softmax(q_values, dim=1)  # Distributional output
        return probs

    def get_q_value(self, probs):
        return torch.sum(probs * self.support, dim=1, keepdim=True)


# Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            torch.tensor(states, dtype=torch.float32),
            torch.tensor(actions, dtype=torch.float32),
            torch.tensor(rewards, dtype=torch.float32).unsqueeze(1),
            torch.tensor(next_states, dtype=torch.float32),
            torch.tensor(dones, dtype=torch.float32).unsqueeze(1),
        )

    def size(self):
        return len(self.buffer)


# Projection for Distributional Critic
def project_distribution(probs, rewards, dones, gamma, atoms, v_min, v_max, delta_z, batch_size):
    target_support = torch.linspace(v_min, v_max, atoms)
    projected_probs = torch.zeros((batch_size, atoms), dtype=torch.float32)

    for i in range(batch_size):
        tz = rewards[i] + gamma * (1 - dones[i]) * target_support
        tz = torch.clamp(tz, v_min, v_max)
        b = (tz - v_min) / delta_z
        l = b.floor().long()
        u = b.ceil().long()

        for j in range(atoms):
            if l[j] == u[j]:
                projected_probs[i, l[j]] += probs[i, j]
            else:
                projected_probs[i, l[j]] += probs[i, j] * (u[j] - b[j])
                projected_probs[i, u[j]] += probs[i, j] * (b[j] - l[j])

    return projected_probs


# Train the D4PG agent
def train_d4pg(env, actor, critic, target_actor, target_critic, buffer, actor_optimizer, critic_optimizer, n_episodes=500, batch_size=64):
    gamma = 0.99
    tau = 0.005  # Soft update parameter
    rewards = []
    atoms = critic.atoms
    v_min = critic.v_min
    v_max = critic.v_max
    delta_z = critic.delta_z

    for episode in range(n_episodes):
        state = env.reset()
        episode_reward = 0

        while True:
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
            action = actor(state_tensor).detach().numpy()[0]
            next_state, reward, done, _ = env.step(action)
            buffer.add((state, action, reward, next_state, done))

            if buffer.size() > batch_size:
                # Sample from buffer
                states, actions, rewards_batch, next_states, dones = buffer.sample(batch_size)

                # Update Critic
                target_actions = target_actor(next_states)
                target_probs = target_critic(next_states, target_actions).detach()
                projected_probs = project_distribution(
                    target_probs, rewards_batch, dones, gamma, atoms, v_min, v_max, delta_z, batch_size
                )
                critic_probs = critic(states, actions)
                critic_loss = -torch.sum(projected_probs * torch.log(critic_probs + 1e-6), dim=1).mean()
                critic_optimizer.zero_grad()
                critic_loss.backward()
                critic_optimizer.step()

                # Update Actor
                actor_loss = -critic.get_q_value(critic(states, actor(states))).mean()
                actor_optimizer.zero_grad()
                actor_loss.backward()
                actor_optimizer.step()

                # Soft update of target networks
                for target_param, param in zip(target_actor.parameters(), actor.parameters()):
                    target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

                for target_param, param in zip(target_critic.parameters(), critic.parameters()):
                    target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

            state = next_state
            episode_reward += reward
            if done:
                break

        rewards.append(episode_reward)
        print(f"Episode {episode + 1}/{n_episodes}, Reward: {episode_reward}")

    return rewards


# Function to calculate moving average
def moving_average(data, window_size=50):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')


# Main
env = ContinuousCartPoleWrapper(gym.make("CartPole-v1"))

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
atoms = 51
v_min = 0  # Rescaled to match CartPole rewards
v_max = 500  # Rescaled to match CartPole rewards

actor = Actor(state_dim, action_dim)
critic = DistributionalCritic(state_dim, action_dim, atoms, v_min, v_max)
target_actor = Actor(state_dim, action_dim)
target_critic = DistributionalCritic(state_dim, action_dim, atoms, v_min, v_max)

target_actor.load_state_dict(actor.state_dict())
target_critic.load_state_dict(critic.state_dict())

actor_optimizer = optim.Adam(actor.parameters(), lr=3e-4)
critic_optimizer = optim.Adam(critic.parameters(), lr=3e-4)

buffer = ReplayBuffer(capacity=100000)

# Train the D4PG agent and get rewards
rewards = train_d4pg(env, actor, critic, target_actor, target_critic, buffer, actor_optimizer, critic_optimizer)

# Calculate moving average rewards
window_size = 50
smoothed_rewards = moving_average(rewards, window_size)

# Plot raw rewards and moving average
plt.figure(figsize=(12, 6))
plt.plot(rewards, label="Raw Rewards", alpha=0.5)
plt.plot(range(window_size - 1, len(rewards)), smoothed_rewards, label=f"Moving Average (window={window_size})", color="red")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("D4PG on Continuous CartPole - Raw vs Moving Average Rewards")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# <ipython-input-1-c1c6bef70dbe>:89: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   torch.tensor(states, dtype=torch.float32),
# Episode 1/500, Reward: 8.0
# Episode 2/500, Reward: 10.0
# Episode 3/500, Reward: 11.0
# Episode 4/500, Reward: 12.0
# Episode 5/500, Reward: 10.0
# Episode 6/500, Reward: 10.0
# Episode 7/500, Reward: 11.0
# Episode 8/500, Reward: 10.0
# Episode 9/500, Reward: 9.0
# Episode 10/500, Reward: 10.0
# Episode 11/500, Reward: 10.0
# Episode 12/500, Reward: 10.0
# Episode 13/500, Reward: 10.0
# Episode 14/500, Reward: 10.0
# Episode 15/500, Reward: 9.0
# Episode 16/500, Reward: 10.0
# Episode 17/500, Reward: 9.0
# Episode 18/500, Reward: 10.0
# Episode 19/500, Reward: 8.0
# Episode 20/500, Reward: 10.0
# Episode 21/500, Reward: 10.0
# Episode 22/500, Reward: 9.0
# Episode 23/500, Reward: 10.0
# Episode 24/500, Reward: 9.0
# Episode 25/500, Reward: 9.0
# Episode 26/500, Reward: 10.0
# Episode 27/500, Reward: 8.0
# Episode 28/500, Reward: 10.0
# Episode 29/500, Reward: 10.0
# Episode 30/500, Reward: 9.0
# Episode 31/500, Reward: 10.0
# Episode 32/500, Reward: 8.0
# Episode 33/500, Reward: 9.0
# Episode 34/500, Reward: 9.0
# Episode 35/500, Reward: 10.0
# Episode 36/500, Reward: 10.0
# Episode 37/500, Reward: 9.0
# Episode 38/500, Reward: 9.0
# Episode 39/500, Reward: 10.0
# Episode 40/500, Reward: 10.0
# Episode 41/500, Reward: 10.0
# Episode 42/500, Reward: 8.0
# Episode 43/500, Reward: 10.0
# Episode 44/500, Reward: 10.0
# Episode 45/500, Reward: 10.0
# Episode 46/500, Reward: 10.0
# Episode 47/500, Reward: 10.0
# Episode 48/500, Reward: 8.0
# Episode 49/500, Reward: 9.0
# Episode 50/500, Reward: 9.0
# Episode 51/500, Reward: 10.0
# Episode 52/500, Reward: 9.0
# Episode 53/500, Reward: 10.0
# Episode 54/500, Reward: 9.0
# Episode 55/500, Reward: 9.0
# Episode 56/500, Reward: 10.0
# Episode 57/500, Reward: 9.0
# Episode 58/500, Reward: 8.0
# Episode 59/500, Reward: 9.0
# Episode 60/500, Reward: 8.0
# Episode 61/500, Reward: 9.0
# Episode 62/500, Reward: 10.0
# Episode 63/500, Reward: 10.0
# Episode 64/500, Reward: 10.0
# Episode 65/500, Reward: 9.0
# Episode 66/500, Reward: 9.0
# Episode 67/500, Reward: 10.0
# Episode 68/500, Reward: 10.0
# Episode 69/500, Reward: 8.0
# Episode 70/500, Reward: 10.0
# Episode 71/500, Reward: 10.0
# Episode 72/500, Reward: 9.0
# Episode 73/500, Reward: 9.0
# Episode 74/500, Reward: 11.0
# Episode 75/500, Reward: 11.0
# Episode 76/500, Reward: 14.0
# Episode 77/500, Reward: 10.0
# Episode 78/500, Reward: 15.0
# Episode 79/500, Reward: 16.0
# Episode 80/500, Reward: 12.0
# Episode 81/500, Reward: 14.0
# Episode 82/500, Reward: 14.0
# Episode 83/500, Reward: 18.0
# Episode 84/500, Reward: 16.0
# Episode 85/500, Reward: 17.0
# Episode 86/500, Reward: 12.0
# Episode 87/500, Reward: 14.0
# Episode 88/500, Reward: 15.0
# Episode 89/500, Reward: 17.0
# Episode 90/500, Reward: 13.0
# Episode 91/500, Reward: 14.0
# Episode 92/500, Reward: 18.0
# Episode 93/500, Reward: 17.0
# Episode 94/500, Reward: 23.0
# Episode 95/500, Reward: 31.0
# Episode 96/500, Reward: 20.0
# Episode 97/500, Reward: 12.0
# Episode 98/500, Reward: 11.0
# Episode 99/500, Reward: 10.0
# Episode 100/500, Reward: 9.0
# Episode 101/500, Reward: 9.0
# Episode 102/500, Reward: 9.0
# Episode 103/500, Reward: 9.0
# Episode 104/500, Reward: 9.0
# Episode 105/500, Reward: 9.0
# Episode 106/500, Reward: 10.0
# Episode 107/500, Reward: 9.0
# Episode 108/500, Reward: 8.0
# Episode 109/500, Reward: 9.0
# Episode 110/500, Reward: 9.0
# Episode 111/500, Reward: 10.0
# Episode 112/500, Reward: 10.0
# Episode 113/500, Reward: 10.0
# Episode 114/500, Reward: 10.0
# Episode 115/500, Reward: 9.0
# Episode 116/500, Reward: 10.0
# Episode 117/500, Reward: 9.0
# Episode 118/500, Reward: 10.0
# Episode 119/500, Reward: 9.0
# Episode 120/500, Reward: 10.0
# Episode 121/500, Reward: 9.0
# Episode 122/500, Reward: 10.0
# Episode 123/500, Reward: 10.0
# Episode 124/500, Reward: 10.0
# Episode 125/500, Reward: 10.0
# Episode 126/500, Reward: 10.0
# Episode 127/500, Reward: 9.0
# Episode 128/500, Reward: 10.0
# Episode 129/500, Reward: 10.0
# Episode 130/500, Reward: 9.0
# Episode 131/500, Reward: 10.0
# Episode 132/500, Reward: 9.0
# Episode 133/500, Reward: 9.0
# Episode 134/500, Reward: 9.0
# Episode 135/500, Reward: 9.0
# Episode 136/500, Reward: 9.0
# Episode 137/500, Reward: 10.0
# Episode 138/500, Reward: 9.0
# Episode 139/500, Reward: 10.0
# Episode 140/500, Reward: 9.0
# Episode 141/500, Reward: 9.0
# Episode 142/500, Reward: 9.0
# Episode 143/500, Reward: 10.0
# Episode 144/500, Reward: 9.0
# Episode 145/500, Reward: 10.0
# Episode 146/500, Reward: 10.0
# Episode 147/500, Reward: 8.0
# Episode 148/500, Reward: 9.0
# Episode 149/500, Reward: 9.0
# Episode 150/500, Reward: 8.0
# Episode 151/500, Reward: 10.0
# Episode 152/500, Reward: 8.0
# Episode 153/500, Reward: 10.0
# Episode 154/500, Reward: 10.0
# Episode 155/500, Reward: 10.0
# Episode 156/500, Reward: 9.0
# Episode 157/500, Reward: 9.0
# Episode 158/500, Reward: 9.0
# Episode 159/500, Reward: 10.0
# Episode 160/500, Reward: 9.0
# Episode 161/500, Reward: 9.0
# Episode 162/500, Reward: 9.0
# Episode 163/500, Reward: 9.0
# Episode 164/500, Reward: 9.0
# Episode 165/500, Reward: 10.0
# Episode 166/500, Reward: 9.0
# Episode 167/500, Reward: 9.0
# Episode 168/500, Reward: 10.0
# Episode 169/500, Reward: 9.0
# Episode 170/500, Reward: 9.0
# Episode 171/500, Reward: 10.0
# Episode 172/500, Reward: 10.0
# Episode 173/500, Reward: 9.0
# Episode 174/500, Reward: 10.0
# Episode 175/500, Reward: 9.0
# Episode 176/500, Reward: 9.0
# Episode 177/500, Reward: 9.0
# Episode 178/500, Reward: 11.0
# Episode 179/500, Reward: 8.0
# Episode 180/500, Reward: 10.0
# Episode 181/500, Reward: 10.0
# Episode 182/500, Reward: 10.0
# Episode 183/500, Reward: 9.0
# Episode 184/500, Reward: 10.0
# Episode 185/500, Reward: 9.0
# Episode 186/500, Reward: 11.0
# Episode 187/500, Reward: 9.0
# Episode 188/500, Reward: 9.0
# Episode 189/500, Reward: 10.0
# Episode 190/500, Reward: 10.0
# Episode 191/500, Reward: 10.0
# Episode 192/500, Reward: 9.0
# Episode 193/500, Reward: 9.0
# Episode 194/500, Reward: 10.0
# Episode 195/500, Reward: 10.0
# Episode 196/500, Reward: 10.0
# Episode 197/500, Reward: 9.0
# Episode 198/500, Reward: 9.0
# Episode 199/500, Reward: 10.0
# Episode 200/500, Reward: 9.0
# Episode 201/500, Reward: 9.0
# Episode 202/500, Reward: 10.0
# Episode 203/500, Reward: 10.0
# Episode 204/500, Reward: 8.0
# Episode 205/500, Reward: 8.0
# Episode 206/500, Reward: 10.0
# Episode 207/500, Reward: 10.0
# Episode 208/500, Reward: 9.0
# Episode 209/500, Reward: 8.0
# Episode 210/500, Reward: 10.0
# Episode 211/500, Reward: 9.0
# Episode 212/500, Reward: 9.0
# Episode 213/500, Reward: 10.0
# Episode 214/500, Reward: 10.0
# Episode 215/500, Reward: 9.0
# Episode 216/500, Reward: 10.0
# Episode 217/500, Reward: 10.0
# Episode 218/500, Reward: 9.0
# Episode 219/500, Reward: 11.0
# Episode 220/500, Reward: 10.0
# Episode 221/500, Reward: 10.0
# Episode 222/500, Reward: 9.0
# Episode 223/500, Reward: 10.0
# Episode 224/500, Reward: 9.0
# Episode 225/500, Reward: 9.0
# Episode 226/500, Reward: 10.0
# Episode 227/500, Reward: 9.0
# Episode 228/500, Reward: 10.0
# Episode 229/500, Reward: 9.0
# Episode 230/500, Reward: 9.0
# Episode 231/500, Reward: 10.0
# Episode 232/500, Reward: 9.0
# Episode 233/500, Reward: 9.0
# Episode 234/500, Reward: 9.0
# Episode 235/500, Reward: 10.0
# Episode 236/500, Reward: 9.0
# Episode 237/500, Reward: 9.0
# Episode 238/500, Reward: 10.0
# Episode 239/500, Reward: 23.0
# Episode 240/500, Reward: 26.0
# Episode 241/500, Reward: 83.0
# Episode 242/500, Reward: 199.0
# Episode 243/500, Reward: 49.0
# Episode 244/500, Reward: 43.0
# Episode 245/500, Reward: 134.0
# Episode 246/500, Reward: 54.0
# Episode 247/500, Reward: 54.0
# Episode 248/500, Reward: 38.0
# Episode 249/500, Reward: 35.0
# Episode 250/500, Reward: 43.0
# Episode 251/500, Reward: 43.0
# Episode 252/500, Reward: 86.0
# Episode 253/500, Reward: 48.0
# Episode 254/500, Reward: 68.0
# Episode 255/500, Reward: 44.0
# Episode 256/500, Reward: 59.0
# Episode 257/500, Reward: 268.0
# Episode 258/500, Reward: 89.0
# Episode 259/500, Reward: 76.0
# Episode 260/500, Reward: 83.0
# Episode 261/500, Reward: 59.0
# Episode 262/500, Reward: 72.0
# Episode 263/500, Reward: 73.0
# Episode 264/500, Reward: 89.0
# Episode 265/500, Reward: 84.0
# Episode 266/500, Reward: 119.0
# Episode 267/500, Reward: 93.0
# Episode 268/500, Reward: 83.0
# Episode 269/500, Reward: 69.0
# Episode 270/500, Reward: 85.0
# Episode 271/500, Reward: 359.0
# Episode 272/500, Reward: 55.0
# Episode 273/500, Reward: 489.0
# Episode 274/500, Reward: 59.0
# Episode 275/500, Reward: 128.0
# Episode 276/500, Reward: 75.0
# Episode 277/500, Reward: 84.0
# Episode 278/500, Reward: 120.0
# Episode 279/500, Reward: 61.0
# Episode 280/500, Reward: 109.0
# Episode 281/500, Reward: 62.0
# Episode 282/500, Reward: 65.0
# Episode 283/500, Reward: 67.0
# Episode 284/500, Reward: 92.0
# Episode 285/500, Reward: 71.0
# Episode 286/500, Reward: 58.0
# Episode 287/500, Reward: 93.0
# Episode 288/500, Reward: 62.0
# Episode 289/500, Reward: 60.0
# Episode 290/500, Reward: 90.0
# Episode 291/500, Reward: 58.0
# Episode 292/500, Reward: 83.0
# Episode 293/500, Reward: 59.0
# Episode 294/500, Reward: 69.0
# Episode 295/500, Reward: 59.0
# Episode 296/500, Reward: 88.0
# Episode 297/500, Reward: 57.0
# Episode 298/500, Reward: 63.0
# Episode 299/500, Reward: 55.0
# Episode 300/500, Reward: 55.0
# Episode 301/500, Reward: 61.0
# Episode 302/500, Reward: 89.0
# Episode 303/500, Reward: 113.0
# Episode 304/500, Reward: 70.0
# Episode 305/500, Reward: 71.0
# Episode 306/500, Reward: 84.0
# Episode 307/500, Reward: 64.0
# Episode 308/500, Reward: 60.0
# Episode 309/500, Reward: 106.0
# Episode 310/500, Reward: 104.0
# Episode 311/500, Reward: 112.0
# Episode 312/500, Reward: 60.0
# Episode 313/500, Reward: 63.0
# Episode 314/500, Reward: 66.0
# Episode 315/500, Reward: 75.0
# Episode 316/500, Reward: 72.0
# Episode 317/500, Reward: 59.0
# Episode 318/500, Reward: 62.0
# Episode 319/500, Reward: 56.0
# Episode 320/500, Reward: 63.0
# Episode 321/500, Reward: 70.0
# Episode 322/500, Reward: 96.0
# Episode 323/500, Reward: 63.0
# Episode 324/500, Reward: 500.0
# Episode 325/500, Reward: 61.0
# Episode 326/500, Reward: 137.0
# Episode 327/500, Reward: 59.0
# Episode 328/500, Reward: 160.0
# Episode 329/500, Reward: 77.0
# Episode 330/500, Reward: 88.0
# Episode 331/500, Reward: 59.0
# Episode 332/500, Reward: 149.0
# Episode 333/500, Reward: 78.0
# Episode 334/500, Reward: 72.0
# Episode 335/500, Reward: 78.0
# Episode 336/500, Reward: 65.0
# Episode 337/500, Reward: 87.0
# Episode 338/500, Reward: 70.0
# Episode 339/500, Reward: 84.0
# Episode 340/500, Reward: 114.0
# Episode 341/500, Reward: 98.0
# Episode 342/500, Reward: 88.0
# Episode 343/500, Reward: 132.0
# Episode 344/500, Reward: 92.0
# Episode 345/500, Reward: 63.0
# Episode 346/500, Reward: 130.0
# Episode 347/500, Reward: 138.0
# Episode 348/500, Reward: 117.0
# Episode 349/500, Reward: 125.0
# Episode 350/500, Reward: 137.0
# Episode 351/500, Reward: 130.0
# Episode 352/500, Reward: 143.0
# Episode 353/500, Reward: 229.0
# Episode 354/500, Reward: 161.0
# Episode 355/500, Reward: 141.0
# Episode 356/500, Reward: 168.0
# Episode 357/500, Reward: 173.0
# Episode 358/500, Reward: 148.0
# Episode 359/500, Reward: 177.0
# Episode 360/500, Reward: 500.0
# Episode 361/500, Reward: 500.0
# Episode 362/500, Reward: 500.0
# Episode 363/500, Reward: 500.0
# Episode 364/500, Reward: 322.0
# Episode 365/500, Reward: 500.0
# Episode 366/500, Reward: 500.0
# Episode 367/500, Reward: 305.0
# Episode 368/500, Reward: 500.0
# Episode 369/500, Reward: 500.0
# Episode 370/500, Reward: 500.0
# Episode 371/500, Reward: 424.0
# Episode 372/500, Reward: 500.0
# Episode 373/500, Reward: 500.0
# Episode 374/500, Reward: 500.0
# Episode 375/500, Reward: 500.0
# Episode 376/500, Reward: 500.0
# Episode 377/500, Reward: 500.0
# Episode 378/500, Reward: 500.0
# Episode 379/500, Reward: 500.0
# Episode 380/500, Reward: 165.0
# Episode 381/500, Reward: 500.0
# Episode 382/500, Reward: 500.0
# Episode 383/500, Reward: 500.0
# Episode 384/500, Reward: 94.0
# Episode 385/500, Reward: 69.0
# Episode 386/500, Reward: 78.0
# Episode 387/500, Reward: 86.0
# Episode 388/500, Reward: 63.0
# Episode 389/500, Reward: 97.0
# Episode 390/500, Reward: 83.0
# Episode 391/500, Reward: 84.0
# Episode 392/500, Reward: 71.0
# Episode 393/500, Reward: 131.0
# Episode 394/500, Reward: 118.0
# Episode 395/500, Reward: 140.0
# Episode 396/500, Reward: 135.0
# Episode 397/500, Reward: 141.0
# Episode 398/500, Reward: 178.0
# Episode 399/500, Reward: 152.0
# Episode 400/500, Reward: 134.0
# Episode 401/500, Reward: 152.0
# Episode 402/500, Reward: 134.0
# Episode 403/500, Reward: 136.0
# Episode 404/500, Reward: 160.0
# Episode 405/500, Reward: 143.0
# Episode 406/500, Reward: 159.0
# Episode 407/500, Reward: 136.0
# Episode 408/500, Reward: 171.0
# Episode 409/500, Reward: 129.0
# Episode 410/500, Reward: 119.0
# Episode 411/500, Reward: 115.0
# Episode 412/500, Reward: 126.0
# Episode 413/500, Reward: 125.0
# Episode 414/500, Reward: 132.0
# Episode 415/500, Reward: 162.0
# Episode 416/500, Reward: 134.0
# Episode 417/500, Reward: 127.0
# Episode 418/500, Reward: 158.0
# Episode 419/500, Reward: 113.0
# Episode 420/500, Reward: 113.0
# Episode 421/500, Reward: 163.0
# Episode 422/500, Reward: 122.0
# Episode 423/500, Reward: 134.0
# Episode 424/500, Reward: 109.0
# Episode 425/500, Reward: 110.0
# Episode 426/500, Reward: 112.0
# Episode 427/500, Reward: 123.0
# Episode 428/500, Reward: 125.0
# Episode 429/500, Reward: 124.0
# Episode 430/500, Reward: 145.0
# Episode 431/500, Reward: 141.0
# Episode 432/500, Reward: 115.0
# Episode 433/500, Reward: 161.0
# Episode 434/500, Reward: 136.0
# Episode 435/500, Reward: 150.0
# Episode 436/500, Reward: 128.0
# Episode 437/500, Reward: 129.0
# Episode 438/500, Reward: 170.0
# Episode 439/500, Reward: 159.0
# Episode 440/500, Reward: 149.0
# Episode 441/500, Reward: 139.0
# Episode 442/500, Reward: 155.0
# Episode 443/500, Reward: 194.0
# Episode 444/500, Reward: 209.0
# Episode 445/500, Reward: 232.0
# Episode 446/500, Reward: 500.0
# Episode 447/500, Reward: 500.0
# Episode 448/500, Reward: 500.0
# Episode 449/500, Reward: 500.0
# Episode 450/500, Reward: 500.0
# Episode 451/500, Reward: 500.0
# Episode 452/500, Reward: 500.0
# Episode 453/500, Reward: 500.0
# Episode 454/500, Reward: 500.0
# Episode 455/500, Reward: 500.0
# Episode 456/500, Reward: 500.0
# Episode 457/500, Reward: 500.0
# Episode 458/500, Reward: 500.0
# Episode 459/500, Reward: 500.0
# Episode 460/500, Reward: 500.0
# Episode 461/500, Reward: 500.0
# Episode 462/500, Reward: 500.0
# Episode 463/500, Reward: 500.0
# Episode 464/500, Reward: 500.0
# Episode 465/500, Reward: 500.0
# Episode 466/500, Reward: 500.0
# Episode 467/500, Reward: 500.0
# Episode 468/500, Reward: 500.0
# Episode 469/500, Reward: 500.0
# Episode 470/500, Reward: 500.0
# Episode 471/500, Reward: 500.0
# Episode 472/500, Reward: 401.0
# Episode 473/500, Reward: 310.0
# Episode 474/500, Reward: 268.0
# Episode 475/500, Reward: 253.0
# Episode 476/500, Reward: 218.0
# Episode 477/500, Reward: 231.0
# Episode 478/500, Reward: 205.0
# Episode 479/500, Reward: 206.0
# Episode 480/500, Reward: 216.0
# Episode 481/500, Reward: 211.0
# Episode 482/500, Reward: 189.0
# Episode 483/500, Reward: 211.0
# Episode 484/500, Reward: 231.0
# Episode 485/500, Reward: 230.0
# Episode 486/500, Reward: 242.0
# Episode 487/500, Reward: 256.0
# Episode 488/500, Reward: 273.0
# Episode 489/500, Reward: 267.0
# Episode 490/500, Reward: 249.0
# Episode 491/500, Reward: 254.0
# Episode 492/500, Reward: 312.0
# Episode 493/500, Reward: 327.0
# Episode 494/500, Reward: 318.0
# Episode 495/500, Reward: 376.0
# Episode 496/500, Reward: 418.0
# Episode 497/500, Reward: 435.0
# Episode 498/500, Reward: 448.0
# Episode 499/500, Reward: 500.0
# Episode 500/500, Reward: 473.0
